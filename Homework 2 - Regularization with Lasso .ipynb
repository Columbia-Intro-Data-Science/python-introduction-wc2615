# %% [markdown]
# # Introduction
#
#
# In this homework, you'll be required to load in a dataset which has about 500 features. By using
# Lasso ($L^1$) regression, we'll find the optimal constraint on the $L^1$ norm which gives us the best
# $R^2$. Then we'll plot the results.
#
# Recall we minimize the following on ** training data: $(x_i,y_i)$**
#
# $$\min_{\beta} \frac{1}{N} \sum_{i=1}^N (y_i - \beta \cdot x_i)^2 + \lambda \|\beta \|_{L^1}.$$
#
#
# Denoting $\beta_{\lambda}$ as the minimum of the above, we then choose $\lambda$ to maximize $R^2$ on **testing data: $(x_j,y_j)$**
#
# $$ \max_{\lambda} 1 - \frac{\sum_{j} (y_j - \beta_{\lambda} \cdot x_j)^2}{\sum_j (y_j - \bar y)^2}$$

# %% [markdown]
# # Lasso Regularization

# %% [markdown]
# ## Problem 1

# %% [markdown]
# a) Load in hw2data.csv from ../data into a pandas dataframe.

# %%
import pandas as pd
import pylab as plt
import seaborn
from sklearn.linear_model import LinearRegression
import numpy.random as nprnd
import random
import json
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
pd.set_option('display.max_columns', 500)
# %matplotlib inline
df = pd.read_csv('https://raw.githubusercontent.com/Columbia-Intro-Data-Science/APMAE4990-/master/data/hw2data.csv')
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.382732 -0.034242  1.096347 -0.234216 -0.347451 -0.581268 -1.632635
# 1  0.555963  0.892474 -0.422315  0.104714  0.228053  0.201480  0.540774
# 2  0.013240 -0.121945  0.339059 -0.589632 -0.895816  0.548328  0.098667
# 3 -1.532921 -1.711970  0.046135 -0.958374 -0.080812 -0.703859 -0.770784
# 4 -1.619685  0.572627  1.902618 -0.775664 -0.188090 -1.035748  1.177830
#
#           7         8         9        10        11        12        13  \
# 0 -1.567768 -1.179158  1.301428  0.895260  1.374964 -1.332212 -1.968625
# 1 -1.818078 -0.049324  0.239034 -1.000330  1.673986  0.161559  1.563405
# 2  0.197181  1.059027 -1.022564 -0.855240  1.257220 -1.482883 -1.309412
# 3 -0.480845  0.703586  0.929145  0.371173 -0.989823  0.643631  0.688897
# 4 -2.305167 -2.263660  0.375020 -0.082344 -0.479623 -0.301095  0.536988
#
#          14        15        16        17        18        19        20  \
# ...

# %% [markdown]
# b) Set y to be the y variable in the dataframe from a and X to be the remaining features.

# %%
y = df['y']
X = df.drop(['y'],1)

# %%
X.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.382732 -0.034242  1.096347 -0.234216 -0.347451 -0.581268 -1.632635
# 1  0.555963  0.892474 -0.422315  0.104714  0.228053  0.201480  0.540774
# 2  0.013240 -0.121945  0.339059 -0.589632 -0.895816  0.548328  0.098667
# 3 -1.532921 -1.711970  0.046135 -0.958374 -0.080812 -0.703859 -0.770784
# 4 -1.619685  0.572627  1.902618 -0.775664 -0.188090 -1.035748  1.177830
#
#           7         8         9        10        11        12        13  \
# 0 -1.567768 -1.179158  1.301428  0.895260  1.374964 -1.332212 -1.968625
# 1 -1.818078 -0.049324  0.239034 -1.000330  1.673986  0.161559  1.563405
# 2  0.197181  1.059027 -1.022564 -0.855240  1.257220 -1.482883 -1.309412
# 3 -0.480845  0.703586  0.929145  0.371173 -0.989823  0.643631  0.688897
# 4 -2.305167 -2.263660  0.375020 -0.082344 -0.479623 -0.301095  0.536988
#
#          14        15        16        17        18        19        20  \
# ...

# %%
y.head()
# Out:
# 0    -2.663126
# 1    10.399650
# 2   -21.762801
# 3     2.139453
# 4     0.194017
# Name: y, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler()
X_scaled = X.as_matrix().astype(np.float)
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# c) As shown in the Booking.com example, using Lasso regression, find the regularization strength
# which optimizes the $R^2$.
#
# **Hint:** Take a range of alpha from `np.logspace(-8,-3,1000)`

# %%
# Randomly split data into training/testing sets
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split (X_scaled, y, test_size=0.2, random_state=1)


plt.subplot(2, 1, 1)
# Create linear regression object
alphas = np.logspace(-8, -3, 1000)
from sklearn.linear_model import Lasso
scores = []

for alpha in alphas:
    regr = Lasso(alpha=alpha)

    # Train the model using the training sets
    regr.fit(X_train, y_train)
    scores.append(regr.score(X_test,y_test))
plt.plot(alphas,scores)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
best_alpha=alphas[np.argmax(scores)]
best_alpha
# Out:
# 0.00085100072471222467

# %% [markdown]
# The regularisation strength that optimises the R^2 is 0.000851.

# %% [markdown]
# d) Plot the training perforamnce versus the testing performance, and observe whree the test performance is
# maximized. I've written an outline of the code you need.

# %%
alphas = np.logspace(-8, -3, 1000)
train_errors = list()
test_errors = list()
for alpha in alphas:
    #enet.set_params(alpha=alpha)
    regr = Lasso(alpha=alpha)
    regr.fit(X_train, y_train)
    train_errors.append(regr.score(X_train, y_train))
    test_errors.append(regr.score(X_test, y_test))
i_alpha_optim = np.argmax(test_errors)
alpha_optim = alphas[i_alpha_optim]
print("Optimal regularization parameter : %s" % alpha_optim)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Optimal regularization parameter : 0.000851000724712

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.subplot(2, 1, 1)


plt.semilogx(alphas, train_errors, label='Train')
plt.semilogx(alphas, test_errors, label='Test')
plt.vlines(alpha_optim, plt.ylim()[0], np.max(test_errors), color='k',
           linewidth=3, label='Optimum on test')
plt.legend(loc='lower left')
plt.ylim([0, 1.2])
plt.xlabel('Regularization parameter')
plt.ylabel('Performance')

plt.legend()
plt.subplots_adjust(0.09, 0.04, 0.94, 0.94, 0.26, 0.26)
plt.show()

# %% [markdown]
# e) Plot the top coefficients based on this optimal paramter. Why do you think so many are zero?

# %%
best_alpha=alphas[np.argmax(scores)]
best_alpha
# Out:
# 0.00085100072471222467

# %%
regr2 = Lasso(alpha=best_alpha)
regr2.fit(X_train,y_train)
regr2.coef_
# Out:
# array([  1.79512515e+00,   4.28058956e-01,   1.02495194e+00,
#          2.16181706e+00,   1.88007097e+00,  -9.22523397e-01,
#          9.98550767e-01,  -1.44266823e-01,  -1.08296105e-01,
#          4.39024044e-01,   1.40042660e-01,   1.43487546e+00,
#          8.00159278e-01,   1.19044517e-01,   4.03113141e-01,
#          3.27695606e-01,   1.55687627e+00,  -1.99425788e-01,
#          3.18252663e-01,  -8.77089120e-01,  -2.59447225e+00,
#          7.03309490e-01,   8.03942648e-01,  -7.45731144e-01,
#          2.21206357e+00,  -1.34479108e+00,   4.50578249e-02,
#         -1.94942629e-01,   1.63814013e+00,   1.37969766e+00,
#          1.60951745e-01,   3.70411609e-01,  -8.62005938e-01,
#         -1.91643178e+00,  -3.32830510e-01,   1.60120113e-01,
#          1.17305740e+00,   1.20712167e+00,  -3.74019293e-01,
#         -3.15945961e-01,  -1.08993885e+00,  -1.46032968e+00,
#         -1.76164337e+00,   1.97538839e+00,  -5.04536896e-01,
# ...

# %%
df_coeffs = pd.DataFrame({'coeffs':regr2.coef_, 'name':range(len(regr2.coef_))})
df_top20 = df_coeffs.sort_values('coeffs')[::-1]
df_top20[0:20].plot(x='name',y='coeffs',kind='bar')

plt.show()

# %%
df_coeffs = pd.DataFrame({'coeffs':regr2.coef_, 'name':range(len(regr2.coef_))})
df_coeffs=df_coeffs.sort_values(['coeffs'])
df_coeffs[::-1].plot(x='name',y='coeffs',kind='bar',figsize=(15,8))

plt.show()

# %%
from IPython.display import Image
Image("https://i.stack.imgur.com/oVJDB.png")

# %% [markdown]
# Regularization is applied in the case of a large machine learning model to avoid the problem of overfitting by essentially reducing its size. A way of such regularization is to ensure that the trained model is sparse, such that most of the components are zeros to effectively reduce the model size. This can be done using L1 (Lasso) regularization, given its special shape.
#
# From the figure above, β̂ gives the unconstrained least squares estimate, while the red ellipses represent the contours of the least squares error function in terms of the parameters β1 and β2. The error function is minimized at β̂ and increases in value with the expansion of the eliipses without constraints. On the other hand, the feasible regions for L1 and L2 regressions are shown by the diamond and disk blue regions respectively.
#
# With the Lasso regression here, to minimise the error function while maintaining feasibility, the intersection produced with the L1 constraint is more likely to have a component of the solution that is zero for a sparse solution given the corners with the diamond feasible region, where these corners are more like to intersect with the ellipses that extend diagonally and send the corresponding coefficient to zero. Hence, this non-uniformly convex property of L1 tends to produce a sparse solution that sends many of the coefficients to zero.

# %% [markdown]
# f) Compute the $R^2$ with the optimal coefficient found above on 5 folds using cross_val_score and plot the
# results. Does the model work well on all random subsets?

# %%
from sklearn.model_selection import cross_val_score

# %%
best_alpha=alphas[np.argmax(scores)]
best_alpha
# Out:
# 0.00085100072471222467

# %%
regr3 = Lasso(alpha=best_alpha)
scores3 = cross_val_score(regr3, X_scaled, y, cv=5)
scores3
# Out:
# array([ 0.99994002,  0.99999741,  0.99999763,  0.99999555,  0.99999125])

# %%
regr3 = Lasso(alpha=best_alpha)
scores3 = cross_val_score(regr3, X_scaled, y, cv=5)
plt.ylim([-1,1])
plt.xlabel('lambda')
plt.ylabel('R^2')
plt.title('Performance on 5 folds with lambda=' + str(alpha))
plt.bar(range(1,6),scores3)
plt.show()

# %% [markdown]
# As shown above, the model appears to work very well on all random subsets given the high R^2 approximating to 1, indicating ~100% goodness of fit.

# %% [markdown]
# f) Repeat e) but using cross validation. Use error bars on the features which are the standard deviation of the
# coefficiens obtained above. For this problem I"ll walk you through the code. You just need to apply your optimal
# $\alpha$ found above.

# %%
from sklearn.cross_validation import KFold
from sklearn import preprocessing
def run_cv_coeffs(X,y,clf_class,**kwargs):
    # Construct a kfolds object
    kf = KFold(len(y),n_folds=5,shuffle=True)
    y_pred = y.copy()
    coeffs=[]
    # Iterate through folds
    for train_index, test_index in kf:
        
        X_train, X_test = X[train_index], X[test_index]
        y_train = y[train_index]
        # Initialize a classifier with key word arguments
        clf = clf_class(**kwargs)
        clf.fit(X_train,y_train)
        y_pred[test_index] = clf.predict(X_test)
        coeffs.append(clf.coef_)
    return coeffs

scaler = preprocessing.StandardScaler()
X_scaled = X.as_matrix().astype(np.float)
X_scaled = scaler.fit_transform(X)

coeffs=run_cv_coeffs(X_scaled,np.array(y),Lasso,alpha=best_alpha)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
def get_coeffs(coeffs):
    coeffs_avgd = [(coeffs[0][i] + coeffs[1][i] + coeffs[2][i] + coeffs[3][i] + coeffs[4][i])/5 for i in range(0,len(X.columns))]
    coeffs_std = [np.std([coeffs[0][i],coeffs[1][i],coeffs[2][i],coeffs[3][i],coeffs[4][i]]) for i in range(0,len(X.columns))]
    return coeffs_avgd, coeffs_std
coeffs_avg,coeffs_std=get_coeffs(coeffs)

# %%
dfCoeffs = pd.DataFrame({'type':X.columns.values, 'coef':coeffs_avg, 'std':coeffs_std})
dfCoeffs = dfCoeffs[(dfCoeffs['coef']>1) |(dfCoeffs['coef']<-1) ]
plt.figure(figsize=(15,15))
dfCoeffs_sorted = dfCoeffs.sort_values(['coef'])[::-1]
yerr_vals = dfCoeffs_sorted['std'].values
dfCoeffs_sorted.plot(x='type',y='coef',kind='bar',yerr=yerr_vals,figsize=(10,10))
